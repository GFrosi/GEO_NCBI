# %%
import pandas as pd
import numpy as np
import subprocess
import os

pd.set_option('display.max_rows', 20)

df_ftp_address = pd.read_csv('/Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GSE_FTP_Hs_ChipSeq.csv' , sep=',')
df_ftp_address
# Out:
#             GSE                                            Address  \
# 0     GSE140664  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE140nn...
# 1     GSE138674  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE138nn...
# 2     GSE141497  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE141nn...
# 3     GSE137662  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE137nn...
# 4     GSE137661  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE137nn...
# ...         ...                                                ...
# 5850   GSE12781  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE12nnn...
# 5851   GSE11673  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5852   GSE11672  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5853   GSE11892  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5854   GSE10437  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE10nnn...
#
#                                            Full_Address
# 0     ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE140nn...
# 1     ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE138nn...
# 2     ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE141nn...
# 3     ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE137nn...
# 4     ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE137nn...
# ...                                                 ...
# 5850  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE12nnn...
# 5851  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5852  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5853  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE11nnn...
# 5854  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE10nnn...
#
# [5855 rows x 3 columns]

# %%
#all XMLs except the 157 missing
def create_dir(path):    
    try:
        os.mkdir(path)
        print("Directory {} done".format(path))
    except OSError:
        print("Directory {} failed".format(path))
            

root_path = '/Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml'
prefix_dir = 'GEO_'
counter = 1                                                                  

path = os.path.join(root_path , prefix_dir + str(counter))
create_dir(path)


#create the correct link and download the xml files
for index, row in df_ftp_address.iterrows():    
    if (index + 1) % 300 == 0:  
        counter += 1
        path = os.path.join(root_path, prefix_dir + str(counter))
        create_dir(path)    
        
    #sample_name = row["Address"].split("/")
    link = row["Full_Address"] #+ sample_name[6] + "_family.xml.tgz" #we can keep in this form, or get the full address
    subprocess.run(['wget', link, '-P', path])
# Out:
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_1 failed
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_2 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_3 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_4 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_5 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_6 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_7 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_8 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_9 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_10 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_11 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_12 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_13 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_14 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_15 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_16 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_17 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_18 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_19 done
# Directory /Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/GEO-data-xml/GEO_20 done
