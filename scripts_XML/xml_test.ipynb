# %%
from xml.dom import minidom
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('esummary.xml')
root = tree.getroot()
root
# Out:
# <Element 'eSummaryResult' at 0x7f3299bd3908>

# %%
mydoc = minidom.parse('esummary.xml')
mydoc

# %%
titles = mydoc.getElementsByTagName('Accession')
titles
# Out:
# [<DOM Element: Accession at 0x7f32c03c79c8>,
#  <DOM Element: Accession at 0x7f32c02a7df0>,
#  <DOM Element: Accession at 0x7f32c02ab2a8>,
#  <DOM Element: Accession at 0x7f32c02ad6d0>,
#  <DOM Element: Accession at 0x7f32c02afaf8>,
#  <DOM Element: Accession at 0x7f32c02b2f20>,
#  <DOM Element: Accession at 0x7f32c02363d8>,
#  <DOM Element: Accession at 0x7f32c0238800>,
#  <DOM Element: Accession at 0x7f32c023ac28>,
#  <DOM Element: Accession at 0x7f32c023f0e0>,
#  <DOM Element: Accession at 0x7f32c0241508>,
#  <DOM Element: Accession at 0x7f32c0243930>,
#  <DOM Element: Accession at 0x7f32c0245d58>,
#  <DOM Element: Accession at 0x7f32c0249210>,
#  <DOM Element: Accession at 0x7f32c024b638>,
#  <DOM Element: Accession at 0x7f32c024ea60>,
#  <DOM Element: Accession at 0x7f32c0252e88>,
#  <DOM Element: Accession at 0x7f32c0257340>,
#  <DOM Element: Accession at 0x7f32c0259768>,
#  <DOM Element: Accession at 0x7f32c025db90>,
#  <DOM Element: Accession at 0x7f32c0262048>,
# ...
