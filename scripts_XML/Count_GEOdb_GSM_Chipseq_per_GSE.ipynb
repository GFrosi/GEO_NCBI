# %%
#Move on geometadb no gpl - check how many GSM are related with chipseq data 

import pandas as pd
import numpy as np

df2 = pd.read_csv('/Users/gfrosi/Documents/Frosi_lab_jacques/XML_TEST/HS_df_chipseq_to_work_no_gpl.csv', sep=',')
df2.columns
# Out:
# Index(['gse', 'type', 'title', 'summary', 'overall_design', 'status',
#        'pubmed_id', 'gsm', 'title..9', 'type..10', 'gpl', 'organism_ch1',
#        'series_id', 'source_name_ch1', 'characteristics_ch1',
#        'supplementary_file', 'characteristics_ch2'],
#       dtype='object')

# %%
#filter the table by chip-seq in gsm fields and then, group.by (gse) and count gsm

df2_chipseq = df2[df2['title..9'].str.contains('chip-seq', case=False) | df2['characteristics_ch1'].str.contains('chip-seq', case=False) ]
df2_chipseq
# Out:
#              gse                                               type  \
# 15      GSE12781  Genome binding/occupancy profiling by high thr...
# 17      GSE12782  Genome binding/occupancy profiling by high thr...
# 19      GSE12783  Genome binding/occupancy profiling by high thr...
# 21      GSE12783  Genome binding/occupancy profiling by high thr...
# 30      GSE13008  Genome binding/occupancy profiling by high thr...
# ...          ...                                                ...
# 47110  GSE106146  Genome binding/occupancy profiling by high thr...
# 47111  GSE106146  Genome binding/occupancy profiling by high thr...
# 47112  GSE106146  Genome binding/occupancy profiling by high thr...
# 47113  GSE106146  Genome binding/occupancy profiling by high thr...
# 47114  GSE106146  Genome binding/occupancy profiling by high thr...
#
#                                                    title  \
# 15           PolII transcription factor in Human HeLa S3
# ...
